# %% [markdown]
# ## Visualize migest.out connectivity matrix

# %%
Packages <- c("dplyr", "ggplot2","rdist", "fields", "stringr", "reshape2", "splitstackshape", "readr", "adegenet", "pegas", "poppr", "ade4", "dplyr", "tidyr", "stringr", "tidyverse", "tibble", "ggfortify", "lubridate", "RColorBrewer", "vegan", "vcfR")

invisible(suppressPackageStartupMessages(lapply(Packages, library, character.only = TRUE)))

setwd('/local/home/katrinac/migest')

source("~/dataprep/conleyte.R")
source("~/dataprep/conlabor.R")
labor <- conlabor()
leyte <- conleyte()

# %%
#read in parentage matches
conn <- read.table(file="~/migest/output/migest_pooled_matrix.txt", sep=" ")

# %%
row <- as.data.frame(c("Gabas", "Caridad Cemetery", "Caridad Proper", "Poroc Rose", "Poroc San Flower", "Visca", "Sitio Baybayon", "Palanas", "Wangag","Magbangon", "Cabataon", "Haina", "Tamakin Dacot", "Sitio Tugas", "Sitio Lonas", "Elementery School", "San Agustin", "Hicgop South"))
col <- "pop"
colnames(row) <- pop
row <- arrange(row, pop)
# Out:
# Error in as.vector(x, "character"): cannot coerce type 'closure' to vector of type 'character'
# Traceback:
#
# 1. `colnames<-`(`*tmp*`, value = structure(function (x)
#  . {
#  .     standardGeneric("pop")
#  . }, generic = structure("pop", package = "adegenet"), package = "adegenet", group = list(), valueClass = character(0), signature = "x", default = `\001NULL\001`, skeleton = (function (x)
#  . stop("invalid call in method dispatch to 'pop' (no default method)",
#  .     domain = NA))(x), class = structure("nonstandardGenericFunction", package = "methods")))
# 2. as.character(structure(function (x)
#  . {
#  .     standardGeneric("pop")
#  . }, generic = structure("pop", package = "adegenet"), package = "adegenet", group = list(), valueClass = character(0), signature = "x", default = `\001NULL\001`, skeleton = (function (x)
#  . stop("invalid call in method dispatch to 'pop' (no default method)",
# ...

# %%
conn <- as.matrix(conn)
image(conn)
# Out:
# Error in image.default(conn): 'z' must be numeric or logical
# Traceback:
#
# 1. image(conn)
# 2. image(conn)
# 3. image.default(conn)
# 4. stop("'z' must be numeric or logical")

# %%
conn
# Out:
#       V1  V2     V3     V4     V5     V6     V7     V8     V9     V10    V11
#  [1,] Pop Pop1   Pop2   Pop3   Pop4   Pop5   Pop6   Pop7   Pop8   Pop9   Pop10
#  [2,] 1   0.0969 0.0001 0.0001 0.0001 0.0001 0.0001 0.0001 0.0001 0.0732 0.6790
#  [3,] 2   0.0001 0.9976 0.0001 0.0001 0.0001 0.0001 0.0002 0.0001 0.0001 0.0001
#  [4,] 3   0.0001 0.0002 0.9979 0.0001 0.0003 0.0001 0.0001 0.0001 0.0001 0.0001
#  [5,] 4   0.0001 0.0001 0.0003 0.0001 0.9981 0.0001 0.0001 0.0001 0.0001 0.0001
#  [6,] 5   0.0001 0.0001 0.0003 0.0001 0.9973 0.0001 0.0003 0.0001 0.0001 0.0001
#  [7,] 6   0.0001 0.0001 0.7174 0.0001 0.0001 0.0001 0.0001 0.0001 0.0001 0.0001
#  [8,] 7   0.0001 0.0001 0.0007 0.0001 0.0001 0.0001 0.6791 0.0001 0.0001 0.0001
#  [9,] 8   0.0746 0.0045 0.0007 0.0001 0.0001 0.0001 0.0934 0.1138 0.0849 0.0001
# [10,] 9   0.0510 0.0001 0.0001 0.0943 0.0001 0.0001 0.0001 0.0649 0.2897 0.0001
# [11,] 10  0.0001 0.0001 0.0001 0.0001 0.0001 0.0001 0.8628 0.1353 0.0001 0.0001
# ...
